# %%
val = int(input("enter value "))
l=[]
k=[]
for x in range(0,val):
    l.append(float(input("enter LB: ")))
print("")
print("Entered weights in LB are",[round(x) for x in l])
for x in l:
    k.append(round(x* 0.454))
print("Entered weights in KG are",k)
# Out:
# enter value 3
# enter LB: 100
# enter LB: 30
# enter LB: 200
#
# Entered weights in LB are [100, 30, 200]
# Entered weights in KG are [45, 14, 91]

# %%
def get_string_alternative(data):
    retun(data[::2])

sentence=input("Please enter a string:")
print(sentence[::2])
# Out:
# Please enter a string:good evening
# go vnn

# %%
file_name=input("Enter a file name: ")
# Out:
# Enter a file name: input.txt

# %%
file=open(file_name,'r')
import re
words=re.sub('[^A-Za-z]+',' ',file.read())
x=words.split()
# print(x)
word_frequency = {}
for word in x:
    count = word_frequency.get(word, 0)
    word_frequency[word] = count + 1

for words in word_frequency.keys():
    print(words, word_frequency[words])
# Out:
# lot 1
# concepts 1
# user 1
# through 2
# Add 1
# complexity 1
# Features 2
# students 3
# accordance 1
# box 1
# Description 1
# replace 1
# your 5
# Basics 1
# SubmissionNote 1
# voice 1
# Installation 1
# Code 4
# each 1
# Check 2
# Cheating 1
# resultant 1
# operations 2
# special 1
# focus 1
# late 4
# we 1
# Also 1
# two 4
# after 3
# loopProgramming 1
# isIn 1
# Instructor 1
# PythonPlease 1
# w 1
# Basic 2
# Overview 1
# playing 2
# differences 1
# version 2
# before 1
# are 1
# https 3
# Googlelink 1
# should 2
# wiki 3
# honesty 1
# ddz 1
# in 6
# class 5
# other 1
# least 1
# I 2
# detailed 1
# work 1
# en 1
# Best 1
# strong 1
# Feedback 2
# them 2
# arithmetic 1
# URL 1
# screenshot 1
# t 1
# it 1
# highly 1
# pairs 1
# forget 1
# for 5
# Note 1
# create 1
# is 4
# programming 2
# numbers 2
# Completeness 1
# Import 1
# min 1
# reverse 1
# Criteria 1
# following 3
# State 1
# video 1
# syllabus 2
# feedback 1
# string 2
# link 2
# lesson 1
# as 4
# Time 1
# Comment 1
# ...
